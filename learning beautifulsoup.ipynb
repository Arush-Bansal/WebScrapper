# %%
import requests
from bs4 import BeautifulSoup

req = requests.get("https://www.easyleadz.com/lists/List-of-Internet-Companies-in-India")
soup = BeautifulSoup(req.content, "html.parser")
print(soup.prettify())
# print(req.content) => contails html webpage
# print(soup.prettify()) // we get intended page
# print(soup.get_text())
# res = soup.title
# print(res.get_text())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <!-- start: HEAD -->
#  <head>
#   <title>
#    List of Top Internet Companies in India
#   </title>
#   <!-- start: META -->
#   <!--[if IE]><meta http-equiv='X-UA-Compatible' content="IE=edge,IE=9,IE=8,chrome=1" /><![endif]-->
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <meta content="Find a list of Top Internet Companies in India, Get contact details of the top decision-makers MD, CEO, CFO, IT Head, HR Head, Sales Head, Marketing Head, Admin Head, Purchase Head." name="description"/>
#   <meta content="Internet Companies India, best internet company in India, internet service providers in India, list of internet companies in India, Media &amp; internet companies in India" name="keywords"/>
#   <meta content="Easyleadz" name="author"/>
# ...

# %%
table = soup.find_all('li')
for ele in table:
    print(ele.text)
# Out:
# Pricing
# Custom Data
# Phone Number Finder
# Contact
# Reliance Jio
# Airtel
# Vodafone Idea
# BSNL
# ACT Fibernet
# APSFL
# MTNL
# Excitel
# Hathway
# You Broadband

# %%
Growth Hackers Digital
WatConsult
iProspect
Webchutney
Foxymoron
Gozoop
Pinstorm
BcWebWise
Mirum

  Adsyndicate
Kinnect
The NineHertz
Web Matriks
Social Pulsar
Creative Monkeys
Bonoboz
City Web
Digital Kangaroos
Studio Pixel
Indian Online Marketing
Webnox Technologies
ShootOrder
ShootOrder
Dot Com Infoway
First Launch
Kreative Machinez
Mind Mingles
ShoutnHike
HitsValue
Digital Zealots

Market and competitive research
CRM & sales funnel strategy
UX consulting
Marketing strategy
Brand positioning & messaging
Automation

Content creation
Digital marketing campaigns
Branding
Marketing personas
 Paid media
Lead nurturing
SEO

User testing & personas
UI design
UX design
Wireframing and prototyping
Graphic print design
Website design
Animations

Website building
Website maintenance and hosting
Platform and data migration
CRM implementation
