# %%
import requests
from bs4 import BeautifulSoup

req = requests.get("https://www.google.com/search?q=webmail&rlz=1C1UEAD_enIN989IN989&oq=webmail&aqs=chrome..69i57j0i8i30j0i271j69i60j69i65j69i60l2j5i44.4680j0j1&sourceid=chrome&ie=UTF-8")
soup = BeautifulSoup(req.content, "html.parser")
print(soup.prettify())
# print(req.content) => contails html webpage
# print(soup.prettify()) // we get intended page
# print(soup.get_text())
# res = soup.title
# print(res.get_text())
# Out:
# <!DOCTYPE html>
# <html lang="en-IN">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    webmail - Google Search
#   </title>
#   <script nonce="s0e0l5R-xCD9wXmXOEBZ3g">
#    (function(){
# ...

# %%
table = soup.find('div', attrs={"class": 'BNeawe s3v9rd AP7Wnd'})
print(table)
# Out:
# <div class="BNeawe s3v9rd AP7Wnd"><div><div class="v9i61e"><div class="BNeawe s3v9rd AP7Wnd">Enterprise Email Solutions Redefined. Login: Webmail | Admin | User CP. Webmail. Email user name. Password Captcha Type characters you see in Captcha</div></div><div><div><div class="BNeawe s3v9rd AP7Wnd"><span class="BNeawe"><a href="/url?q=https://webmail.logix.in/viporg.com/%3Fsession%3Df9d8c490c90d969687b99fed91ea214ac74d97b01eae257e44aa9d5bade97baf1d0ee1bba2314532c4defd3b061acf1dc74d97b01eae257e44aa9d5bade97baf&amp;sa=U&amp;ved=2ahUKEwjjir-Dovf7AhUKSWwGHdhXDXQQjBB6BAgGEAU&amp;usg=AOvVaw0ZYJaRlEnA-CMLOjsBQJR2"><span class="XLloXe AP7Wnd">Enterprise Email Solutions ...</span></a></span></div></div></div></div></div>
